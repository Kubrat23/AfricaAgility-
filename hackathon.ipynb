# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
connect_care = pd.read_csv("salesdaily(2).xls")
connect_care
# Out:
#           datum  M01AB   M01AE  N02BA  N02BE  N05B  N05C   R03   R06  Year  \
# 0      1/2/2014   0.00   3.670   3.40  32.40   7.0   0.0   0.0  2.00  2014
# 1      1/3/2014   8.00   4.000   4.40  50.60  16.0   0.0  20.0  4.00  2014
# 2      1/4/2014   2.00   1.000   6.50  61.85  10.0   0.0   9.0  1.00  2014
# 3      1/5/2014   4.00   3.000   7.00  41.10   8.0   0.0   3.0  0.00  2014
# 4      1/6/2014   5.00   1.000   4.50  21.70  16.0   2.0   6.0  2.00  2014
# ...         ...    ...     ...    ...    ...   ...   ...   ...   ...   ...
# 2101  10/4/2019   7.34   5.683   2.25  22.45  13.0   0.0   1.0  1.00  2019
# 2102  10/5/2019   3.84   5.010   6.00  25.40   7.0   0.0   0.0  0.33  2019
# 2103  10/6/2019   4.00  11.690   2.00  34.60   6.0   0.0   5.0  4.20  2019
# 2104  10/7/2019   7.34   4.507   3.00  50.80   6.0   0.0  10.0  1.00  2019
# 2105  10/8/2019   0.33   1.730   0.50  44.30  20.0   2.0   2.0  0.00  2019
#
#       Month  Hour Weekday Name
# 0         1   248     Thursday
# ...

# %%
connect_care.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2106 entries, 0 to 2105
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datum         2106 non-null   object
#  1   M01AB         2106 non-null   float64
#  2   M01AE         2106 non-null   float64
#  3   N02BA         2106 non-null   float64
#  4   N02BE         2106 non-null   float64
#  5   N05B          2106 non-null   float64
#  6   N05C          2106 non-null   float64
#  7   R03           2106 non-null   float64
#  8   R06           2106 non-null   float64
#  9   Year          2106 non-null   int64
#  10  Month         2106 non-null   int64
#  11  Hour          2106 non-null   int64
#  12  Weekday Name  2106 non-null   object
# dtypes: float64(8), int64(3), object(2)
# memory usage: 214.0+ KB

# %%
connect_care.describe()
# Out:
#              M01AB        M01AE        N02BA        N02BE         N05B  \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean      5.033683     3.895830     3.880441    29.917095     8.853627
# std       2.737579     2.133337     2.384010    15.590966     5.605605
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     2.340000     2.000000    19.000000     5.000000
# 50%       4.990000     3.670000     3.500000    26.900000     8.000000
# 75%       6.670000     5.138000     5.200000    38.300000    12.000000
# max      17.340000    14.463000    16.000000   161.000000    54.833333
#
#               N05C          R03          R06         Year        Month  \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean      0.593522     5.512262     2.900198  2016.401235     6.344255
# std       1.092988     6.428736     2.415816     1.665060     3.386954
# ...

# %%
connect_care["M01AB"].value_counts()
# Out:
# 4.000000     126
# 5.000000     119
# 3.000000     111
# 6.000000      99
# 2.000000      99
#             ...
# 3.543750       1
# 9.320000       1
# 14.000000      1
# 7.666667       1
# 5.180000       1
# Name: M01AB, Length: 218, dtype: int64

# %%
connect_care["M01AE"].value_counts()
# Out:
# 3.000    55
# 2.000    53
# 3.340    52
# 4.000    47
# 2.340    45
#          ..
# 5.970     1
# 4.297     1
# 7.650     1
# 1.802     1
# 1.730     1
# Name: M01AE, Length: 694, dtype: int64

# %%
connect_care["N02BA"].value_counts()
# Out:
# 3.00     217
# 2.00     212
# 4.00     178
# 1.00     147
# 5.00     143
#         ...
# 9.05       1
# 5.55       1
# 7.25       1
# 13.70      1
# 4.55       1
# Name: N02BA, Length: 199, dtype: int64

# %%
connect_care["N02BE"].value_counts()
# Out:
# 15.000    37
# 19.000    36
# 20.000    34
# 18.000    34
# 24.000    34
#           ..
# 30.062     1
# 46.950     1
# 48.100     1
# 68.400     1
# 22.450     1
# Name: N02BE, Length: 713, dtype: int64

# %%
connect_care["N05B"].value_counts()
# Out:
# 6.000000     167
# 7.000000     166
# 5.000000     160
# 4.000000     159
# 9.000000     154
#             ...
# 17.666667      1
# 22.333333      1
# 5.500000       1
# 19.500000      1
# 7.200000       1
# Name: N05B, Length: 77, dtype: int64

# %%
connect_care_14 = connect_care[connect_care["Year"]==2014]
connect_care_14
# Out:
#           datum  M01AB  M01AE  N02BA  N02BE  N05B  N05C   R03  R06  Year  \
# 0      1/2/2014   0.00   3.67    3.4  32.40   7.0   0.0   0.0  2.0  2014
# 1      1/3/2014   8.00   4.00    4.4  50.60  16.0   0.0  20.0  4.0  2014
# 2      1/4/2014   2.00   1.00    6.5  61.85  10.0   0.0   9.0  1.0  2014
# 3      1/5/2014   4.00   3.00    7.0  41.10   8.0   0.0   3.0  0.0  2014
# 4      1/6/2014   5.00   1.00    4.5  21.70  16.0   2.0   6.0  2.0  2014
# ..          ...    ...    ...    ...    ...   ...   ...   ...  ...   ...
# 359  12/27/2014   7.33   5.34    4.4  39.00  26.0   0.0   9.0  3.0  2014
# 360  12/28/2014   2.34  10.76    3.0  80.40  15.0   0.0  13.0  1.0  2014
# 361  12/29/2014   2.33   3.66    4.0  40.00   5.0   1.0   2.0  0.0  2014
# 362  12/30/2014   9.00   5.63    3.8  51.00  18.0   0.0   5.0  2.0  2014
# 363  12/31/2014   5.67   6.33    2.5  41.08  14.0   3.0  10.0  1.0  2014
#
#      Month  Hour Weekday Name
# 0        1   248     Thursday
# ...

# %%
connect_care_14.describe()
# Out:
#             M01AB       M01AE       N02BA       N02BE        N05B        N05C  \
# count  364.000000  364.000000  364.000000  364.000000  364.000000  364.000000
# mean     3.975865    3.453583    4.440842   25.479057   11.854567    0.748970
# std      2.269508    1.983173    2.744396   12.910841    6.245534    1.034132
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.340000    2.000000    2.300000   16.450000    7.000000    0.000000
# 50%      4.000000    3.340000    4.000000   23.300000   11.000000    0.000000
# 75%      5.340000    4.680000    6.000000   32.200000   16.000000    1.000000
# max     12.000000   10.760000   15.000000   80.400000   43.000000    5.000000
#
#               R03         R06    Year       Month        Hour
# count  364.000000  364.000000   364.0  364.000000  364.000000
# mean     3.447802    2.199141  2014.0    6.541209  275.923077
# std      4.893918    1.953728     0.0    3.445115    1.467599
# ...

# %%
connect_care_15 = connect_care[connect_care["Year"]==2015]
connect_care_15
# Out:
#           datum  M01AB  M01AE  N02BA  N02BE  N05B  N05C    R03  R06  Year  \
# 364    1/1/2015   0.00  0.000    0.0   0.00   0.0   0.0   0.00  0.0  2015
# 365    1/2/2015   6.00  5.330    4.9  50.80  13.0   0.0   6.25  2.0  2015
# 366    1/3/2015   9.00  4.670    6.0  57.24  11.0   3.0   0.00  4.0  2015
# 367    1/4/2015   4.68  8.920    3.5  60.10   4.0   0.0   2.00  1.0  2015
# 368    1/5/2015   2.34  3.320    1.0  33.60  14.0   0.0  16.00  3.0  2015
# ..          ...    ...    ...    ...    ...   ...   ...    ...  ...   ...
# 724  12/27/2015   5.33  6.792    5.2  63.50   4.0   0.0  14.00  4.6  2015
# 725  12/28/2015   4.00  5.099    9.2  61.50  18.0   3.0  26.00  1.0  2015
# 726  12/29/2015  10.67  2.330    2.0  71.60   9.0   0.0   2.00  3.0  2015
# 727  12/30/2015   6.66  7.089    2.0  56.40  12.0   0.0   4.00  2.0  2015
# 728  12/31/2015   7.66  6.099    7.6  44.35  18.0   0.0   6.00  1.0  2015
#
#      Month  Hour Weekday Name
# 364      1   276     Thursday
# ...

# %%
connect_care_15.describe()
# Out:
#             M01AB       M01AE       N02BA       N02BE        N05B        N05C  \
# count  365.000000  365.000000  365.000000  365.000000  365.000000  365.000000
# mean     5.193479    4.100282    4.407205   32.666370    8.123288    0.435616
# std      2.721005    2.131227    2.366743   14.411602    4.941680    0.857637
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      3.000000    2.670000    3.000000   22.400000    5.000000    0.000000
# 50%      5.000000    3.990000    4.000000   30.000000    7.000000    0.000000
# 75%      6.670000    5.340000    6.000000   40.750000   11.000000    1.000000
# max     14.180000   11.990000   16.000000   87.200000   33.000000    4.000000
#
#               R03         R06    Year       Month   Hour
# count  365.000000  365.000000   365.0  365.000000  365.0
# mean     4.715753    2.693233  2015.0    6.526027  276.0
# std      5.717015    2.231204     0.0    3.452584    0.0
# ...

# %%
sns.pairplot(connect_care)

# %%
connect_care_14.iloc[:,[1]].sum()
# Out:
# M01AB    1447.215
# dtype: float64

# %%
connect_care_14.iloc[:,[2]].sum()
# Out:
# M01AE    1257.104313
# dtype: float64

# %%
connect_care_14.iloc[:,[3]].sum()
# Out:
# N02BA    1616.4665
# dtype: float64

# %%
connect_care_14.iloc[:,[4]].sum()
# Out:
# N02BE    9274.376875
# dtype: float64

# %%
connect_care_14.iloc[:,[5]].sum()
# Out:
# N05B    4315.0625
# dtype: float64

# %%
connect_care_14.iloc[:,[6]].sum()
# Out:
# N05C    272.625
# dtype: float64

# %%
connect_care_14.iloc[:,[7]].sum()
# Out:
# R03    1255.0
# dtype: float64

# %%
connect_care_14.iloc[:,[8]].sum()
# Out:
# R06    800.4875
# dtype: float64

# %%
connect_care_15.iloc[:,[1]].sum()
# Out:
# M01AB    1895.62
# dtype: float64

# %%
connect_care_15.iloc[:,[2]].sum()
# Out:
# M01AE    1496.603
# dtype: float64

# %%
connect_care_15.iloc[:,[3]].sum()
# Out:
# N02BA    1608.63
# dtype: float64

# %%
connect_care_15.iloc[:,[4]].sum()
# Out:
# N02BE    11923.225
# dtype: float64

# %%
connect_care_15.iloc[:,[5]].sum()
# Out:
# N05B    2965.0
# dtype: float64

# %%
connect_care_15.iloc[:,[6]].sum()
# Out:
# N05C    159.0
# dtype: float64

# %%
connect_care_15.iloc[:,[7]].sum()
# Out:
# R03    1721.25
# dtype: float64

# %%
connect_care_15.iloc[:,[8]].sum()
# Out:
# R06    983.03
# dtype: float64

# %%
connect_care_17 = connect_care[connect_care["Year"]==2017]
connect_care_17
# Out:
#            datum      M01AB      M01AE     N02BA      N02BE       N05B   N05C  \
# 1095    1/1/2017   3.543750   3.956250  1.562500  25.675000   8.750000  1.875
# 1096    1/2/2017   0.212500   0.637500  0.625000  32.000000   0.000000  0.625
# 1097    1/3/2017   6.250000   5.831250  4.625000  66.812500   8.750000  0.000
# 1098    1/4/2017   6.804167   5.970833  6.416667  56.766667  10.000000  1.250
# 1099    1/5/2017   7.504167   7.879167  5.208333  62.208333  14.583333  0.000
# ...          ...        ...        ...       ...        ...        ...    ...
# 1455  12/27/2017   7.000000   4.814000  5.150000  32.700000   9.000000  0.000
# 1456  12/28/2017   7.330000   3.462000  5.100000  35.350000  12.000000  3.000
# 1457  12/29/2017   9.340000   2.066000  2.500000  41.400000  17.000000  0.000
# 1458  12/30/2017   8.680000   8.363000  4.000000  50.000000   8.000000  0.000
# 1459  12/31/2017  13.830000  10.043000  5.300000  70.200000   9.000000  0.000
#
# ...

# %%
connect_care_17.iloc[:,[1]].sum()
# Out:
# M01AB    1846.617083
# dtype: float64

# %%
connect_care_17.iloc[:,[2]].sum()
# Out:
# M01AE    1387.298333
# dtype: float64

# %%
connect_care_17.iloc[:,[3]].sum()
# Out:
# N02BA    1288.295833
# dtype: float64

# %%
connect_care_17.iloc[:,[4]].sum()
# Out:
# N02BE    9258.804833
# dtype: float64

# %%
connect_care_17.iloc[:,[5]].sum()
# Out:
# N05B    2555.541667
# dtype: float64

# %%
connect_care_17.iloc[:,[6]].sum()
# Out:
# N05C    180.333333
# dtype: float64

# %%
connect_care_17.iloc[:,[7]].sum()
# Out:
# R03    1893.614583
# dtype: float64

# %%
connect_care_17.iloc[:,[8]].sum()
# Out:
# R06    988.86
# dtype: float64

# %%
connect_care_18 = connect_care[connect_care["Year"]==2018]
connect_care_18
# Out:
#            datum  M01AB  M01AE  N02BA  N02BE  N05B  N05C   R03  R06  Year  \
# 1460    1/1/2018   0.00  0.000   0.00   0.00   0.0   0.0   0.0  0.0  2018
# 1461    1/2/2018   1.00  5.330   2.25  38.00   3.0   0.0   2.0  2.0  2018
# 1462    1/3/2018   4.67  2.397   3.00  54.00   4.0   0.0  10.0  3.0  2018
# 1463    1/4/2018   6.00  1.099   1.00  39.20   9.0   0.0   1.0  2.0  2018
# 1464    1/5/2018  12.00  6.825   3.00  26.00  11.0   0.0  21.0  1.0  2018
# ...          ...    ...    ...    ...    ...   ...   ...   ...  ...   ...
# 1820  12/27/2018   3.68  3.010   3.05  40.60   8.0   0.0   7.0  0.0  2018
# 1821  12/28/2018  11.67  5.845   1.00  56.40  11.0   6.0   9.0  0.0  2018
# 1822  12/29/2018   6.68  5.611   1.00  68.35   5.0   0.0   7.0  2.0  2018
# 1823  12/30/2018   5.33  7.593   5.00  59.90   6.0   0.0  31.0  3.3  2018
# 1824  12/31/2018   8.00  4.660   5.20  44.50  10.0   0.0   6.0  4.0  2018
#
#       Month  Hour Weekday Name
# 1460      1   276       Monday
# ...

# %%
connect_care_18.iloc[:,[1]].sum()
# Out:
# M01AB    1786.93
# dtype: float64

# %%
connect_care_18.iloc[:,[2]].sum()
# Out:
# M01AE    1389.656
# dtype: float64

# %%
connect_care_18.iloc[:,[3]].sum()
# Out:
# N02BA    1123.8
# dtype: float64

# %%
connect_care_18.iloc[:,[4]].sum()
# Out:
# N02BE    11230.925
# dtype: float64

# %%
connect_care_18.iloc[:,[5]].sum()
# Out:
# N05B    3266.2
# dtype: float64

# %%
connect_care_18.iloc[:,[6]].sum()
# Out:
# N05C    235.0
# dtype: float64

# %%
connect_care_18.iloc[:,[7]].sum()
# Out:
# R03    2655.25
# dtype: float64

# %%
connect_care_18.iloc[:,[8]].sum()
# Out:
# R06    1196.8
# dtype: float64

# %%
plt.bar(['M01AB','M01AE','N02BA','N02BE','N05B','N05C','R03','R06])
